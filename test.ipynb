# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/shivansh_five_class_run_1.csv')
df.head()
# Out:
#    11:19:06.0757  still  baseline  train  448602.031  513506.125  288239.875  \
# 0  11:19:06.0757  still  baseline  train  667719.938   83091.180  -21582.578
# 1  11:19:06.0757  still  baseline  train  -59478.801  325425.500  165232.234
# 2  11:19:06.0757  still  baseline  train -302226.344  641469.062  386358.875
# 3  11:19:06.0784  still  baseline  train -750000.125  651880.500  352940.062
# 4  11:19:06.0784  still  baseline  train -750000.125  750000.062  468263.156
#
#    482351.125  746632.875  -11380.973  ...  564674.938  -0.016  0.971  -0.211  \
# 0  189432.203  669278.875 -463217.656  ...  344193.469  -0.021  0.984  -0.222
# 1  172696.375  623370.938 -502282.250  ...  397402.500  -0.020  0.987  -0.227
# 2   26891.207  606680.375 -232277.188  ...  625265.562  -0.023  0.988  -0.231
# 3  -29250.299  687003.938 -170845.203  ...  688961.562  -0.025  0.990  -0.229
# 4   59446.254  750000.062  298182.656  ...  750000.062  -0.026  0.989  -0.229
#
# ...

# %%
left_leg = df.iloc[:,1]
if left_leg 
print(left_leg)
# Out:
# 0           still
# 1           still
# 2           still
# 3           still
# 4           still
#            ...
# 75890    left_leg
# 75891    left_leg
# 75892    left_leg
# 75893    left_leg
# 75894    left_leg
# Name: still, Length: 75895, dtype: object
